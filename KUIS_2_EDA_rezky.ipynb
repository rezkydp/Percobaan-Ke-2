# %% [markdown]
# <a href="https://colab.research.google.com/github/rezkydp/Percobaan-Ke-2/blob/main/KUIS_2_EDA_rezky.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Understanding Business Problem

# %% [markdown]
# Our business case is to predict customer charges for an insurance company based on given variables. So that the company can decide how much they charge people correctly.

# %% [markdown]
# # 2. Variable Description

# %% [markdown]
# After understanding the business case, we need to know our variables before analyzing them. Thus we have a clear understanding as we go further.
#
# I passed the gathering data step since we already have ready to use data from Kaggle :)
#
# Age: Age of the primary beneficiary
# Sex: Insurance contractor gender, female, male
# BMI: Body mass index, providing an understanding of the body, weights that are relatively high or low relative to height,
# an objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
# Children: Number of children covered by health insurance / Number of dependents
# Smoker: Smoking
# Region: the beneficiary’s residential area in the US, northeast, southeast, southwest and northwest.
# Charges: Individual medical costs billed by health insurance

# %% [markdown]
# # 3. Data Understanding

# %%
import numpy as np
import numpy as pd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Sensor.csv')

# %%
df.head()
# Out:
#    Temperature   Sensor1   Sensor2   Sensor3   Sensor4   Sensor5
# 0    25.431489  0.677916  0.208399  0.033098  0.145758  0.291933
# 1    24.486056  0.801851  0.445989  0.869082  0.499015  0.531490
# 2    20.055087  0.781817  0.040596  0.205773  0.517225  0.598457
# 3    22.781690  0.651030  0.316018  0.945797  0.433242  0.378673
# 4    25.292826  0.292357  0.893463  0.289188  0.490347  0.012502

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3457 entries, 0 to 3456
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  3457 non-null   float64
#  1   Sensor1      3457 non-null   float64
#  2   Sensor2      3457 non-null   float64
#  3   Sensor3      3457 non-null   float64
#  4   Sensor4      3457 non-null   float64
#  5   Sensor5      3457 non-null   float64
# dtypes: float64(6)
# memory usage: 162.2 KB

# %%
df.shape
# Out:
# (3457, 6)

# %%
df.columns
# Out:
# Index(['Temperature', 'Sensor1', 'Sensor2', 'Sensor3', 'Sensor4', 'Sensor5'], dtype='object')

# %%
df.describe()
# Out:
#        Temperature      Sensor1      Sensor2      Sensor3      Sensor4  \
# count  3457.000000  3457.000000  3457.000000  3457.000000  3457.000000
# mean     24.989396     0.502612     0.496721     0.497600     0.495230
# std       2.898912     0.290374     0.293774     0.287507     0.287608
# min      18.982907     0.000243     0.000388     0.000091     0.000244
# 25%      22.542058     0.252100     0.240042     0.249052     0.251254
# 50%      24.972157     0.504355     0.495343     0.506430     0.491202
# 75%      27.396090     0.758330     0.750479     0.750505     0.741194
# max      31.739198     0.999787     0.999965     0.999586     0.999667
#
#            Sensor5
# count  3457.000000
# mean      0.496095
# std       0.289214
# min       0.000254
# 25%       0.241400
# 50%       0.494519
# 75%       0.748835
# max       0.999862

# %%
df.Sensor1.unique()
# Out:
# array([0.67791626, 0.80185136, 0.7818165 , ..., 0.81535867, 0.21700076,
#        0.66226288])

# %% [markdown]
# # 4. Data Cleaning

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Sensor1        0
# Sensor2        0
# Sensor3        0
# Sensor4        0
# Sensor5        0
# dtype: int64

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Temperature, Sensor1, Sensor2, Sensor3, Sensor4, Sensor5]
# Index: []

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %% [markdown]
# # 5. Data visualization

# %%
plt.figure(figsize=(10,6))
sns.distplot(df.Sensor5,color='r')
plt.title('Sensor5 Distribution',size=18)
plt.xlabel('Sensor5',size=14)
plt.xlabel('Density',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.Temperature)
plt.title('Temperature Distribution',size=18)
plt.xlabel('Temperature',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df.Sensor2,color='y')
plt.title('Sensor2 Distribution',size=18)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = 'Sensor3', data = df)
plt.title('Sensor3 Distribution',size=18)
plt.xlabel('Sensor3',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = 'Sensor4', data = df)
plt.title('Sensor4 Distribution',size=18)
plt.xlabel('Sensor4',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = 'Sensor5', data = df)
plt.title('Sensor5 Distribution',size=18)
plt.xlabel('Senso5',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
df.Sensor4.value_counts()
# Out:
# Sensor4
# 0.696307    1
# 0.474586    1
# 0.068899    1
# 0.117102    1
# 0.273307    1
#            ..
# 0.839039    1
# 0.490347    1
# 0.433242    1
# 0.517225    1
# 0.499015    1
# Name: count, Length: 3457, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = 'Sensor5', data = df)
plt.title('Sensor5 Distribution',size=18)
plt.xlabel('Sensor5',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %% [markdown]
# 5.2 Bivariate Analysis
# Bivariate analysis is the analysis of exactly two variables. We will use bivariate analysis to find relationships between two variables.
#
# For bivariate analysis, we usually use boxplot(categorical vs numerical), scatterplot(numerical vs numerical), or contingency table(categorical vs categorical).

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x ='Temperature',y='Sensor2',color='r',data = df)
plt.title('Sensor1 vs Sensor2',size=18)
plt.xlabel('Sensor1',size=14)
plt.ylabel('Sensor2',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Sensor4',data=df)
plt.title('Sensor4',size=18)
# Out:
# Text(0.5, 1.0, 'Sensor4')

# %%
sns.pairplot(df,
                  markers="+", # Changed 'markes' to 'markers'
                  diag_kind="kde",
                  kind='reg',
                  plot_kws={'line_kws':{'color':'#aec6c7'},
                            'scatter_kws': {'alpha':0.7,
                                            'color':'red'}},
                  corner=True);

# %%
plt.figure(figsize=(10,6))
# Select only numerical features for correlation calculation
numerical_df = df.select_dtypes(include=['number'])
sns.heatmap(numerical_df.corr(), annot=True, square=True)
plt.title('Correlation Between Variables', size=18)
plt.xticks(size=13)
plt.yticks(size=13)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x ='Sensor1',y='Sensor2',color='r',data = df)
plt.title('Sensor1 vs Sensor2',size=18)
plt.xlabel('Sensor1',size=14)
plt.ylabel('Sensor2',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Sensor3',data=df)
plt.title('Sensor3',size=18)
# Out:
# Text(0.5, 1.0, 'Sensor3')

# %%
sns.pairplot(df,
                  markers="+", # Changed 'markes' to 'markers'
                  diag_kind="kde",
                  kind='reg',
                  plot_kws={'line_kws':{'color':'#aec6c7'},
                            'scatter_kws': {'alpha':0.7,
                                            'color':'red'}},
                  corner=True);
